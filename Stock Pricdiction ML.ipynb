#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100,min_samples_split=100, random_state=1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100]

predictors = ["Close","Volume","Open","High","Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
print(sp500[predictors].dtypes)
print(sp500[predictors].head())
# Out:
# Close     float64
# Volume      int64
# Open      float64
# High      float64
# Low       float64
# dtype: object
#                                 Close     Volume        Open        High  \
# Date
# 1990-01-02 00:00:00-05:00  359.690002  162070000  353.399994  359.690002
# 1990-01-03 00:00:00-05:00  358.760010  192330000  359.690002  360.589996
# 1990-01-04 00:00:00-05:00  355.670013  177000000  358.760010  358.760010
# 1990-01-05 00:00:00-05:00  352.200012  158530000  355.670013  355.670013
# 1990-01-08 00:00:00-05:00  353.790009  140110000  352.200012  354.239990
#
#                                   Low
# Date
# 1990-01-02 00:00:00-05:00  351.980011
# 1990-01-03 00:00:00-05:00  357.890015
# 1990-01-04 00:00:00-05:00  352.890015
# 1990-01-05 00:00:00-05:00  351.350006
# 1990-01-08 00:00:00-05:00  350.540009

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score

# Fix column types
predictors = ["Close", "Volume", "Open", "High", "Low"]
sp500[predictors] = sp500[predictors].apply(pd.to_numeric, errors='coerce')

# Drop any rows with NaN after conversion
sp500.dropna(subset=predictors + ["Target"], inplace=True)

# Re-split
train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

# Re-train model
model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)
model.fit(train[predictors], train["Target"])

# Predict
preds = model.predict(test[predictors])

# Score
print(precision_score(test["Target"], preds))
# Out:
# 0.639344262295082

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd

preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"],preds)
# Out:
# 0.639344262295082

# %%
combined = pd.concat([test["Target"],preds],axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    3957
# 1    2680
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"],predictions["Predictions"])
# Out:
# 0.5309701492537313

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.537291
# 0    0.462709
# Name: count, dtype: float64

# %%
# Get the latest row of data
latest_data = sp500.iloc[-1:][predictors]

# Predict (0 = price goes DOWN, 1 = price goes UP)
prediction = model.predict(latest_data)
print("Prediction:", "UP 📈" if prediction[0] == 1 else "DOWN 📉")
# Out:
# Prediction: DOWN 📉

# %%
# Get probability of going up vs down
proba = model.predict_proba(latest_data)
print(f"Down probability: {proba[0][0]:.2%}")
print(f"Up probability:   {proba[0][1]:.2%}")
# Out:
# Down probability: 60.60%
# Up probability:   39.40%

# %%
# Pick a specific date
specific_day = sp500.loc["2024-01-15":][predictors].iloc[:1]

prediction = model.predict(specific_day)
print("Prediction:", "UP 📈" if prediction[0] == 1 else "DOWN 📉")
# Out:
# Prediction: DOWN 📉

# %%
import joblib

# Save
joblib.dump(model, "sp500_model.pkl")

# Load it back anytime
model = joblib.load("sp500_model.pkl")
